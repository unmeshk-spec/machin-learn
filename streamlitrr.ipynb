# %%
# !pip install streamlit appdirs
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.1/10.1 MB 93.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 102.5 MB/s eta 0:00:00
# ...

# %%
# %%writefile streamlitapp.py
import streamlit as st
import appdirs as ad
ad.user_cache_dir= lambda *args: './tmp'
st.title("jinsei wa jigoku!")
image_url="https://www.google.com/imgres?q=rick%20ashley&imgurl=https%3A%2F%2Fi.redd.it%2Ffsh2qi0yrbr71.png&imgrefurl=https%3A%2F%2Fwww.reddit.com%2Fr%2FBossfight%2Fcomments%2Fq0u5yf%2F%25F0%259D%2595%25BD%25F0%259D%2596%258E%25F0%259D%2596%2588%25F0%259D%2596%2590_%25F0%259D%2595%25AC%25F0%259D%2596%2598%25F0%259D%2596%258D%25F0%259D%2596%2591%25F0%259D%2596%258A%25F0%259D%2596%259E_%25F0%259D%2595%25B7%25F0%259D%2596%2594%25F0%259D%2596%2597%25F0%259D%2596%2589_%25F0%259D%2595%25BA%25F0%259D%2596%258B_%25F0%259D%2595%25AF%25F0%259D%2596%258E%25F0%259D%2596%2598%25F0%259D%2596%2586%25F0%259D%2596%2595%25F0%259D%2596%2595%25F0%259D%2596%2594%25F0%259D%2596%258E%25F0%259D%2596%2593%25F0%259D%2596%2599%25F0%259D%2596%2592%25F0%259D%2596%258A%25F0%259D%2596%2593%25F0%259D%2596%2599%2F&docid=YSnhGHzENrrLTM&tbnid=zIqWBdwEW3nc8M&vet=12ahUKEwjT6KGFxLmQAxUXdPUHHfXOKTIQM3oECB0QAA..i&w=1200&h=1200&hcb=2&ved=2ahUKEwjT6KGFxLmQAxUXdPUHHfXOKTIQM3oECB0QAA"
st.image("image_url")
st.title("1 one firm for artists and graphics")
st.badge("hitori",color="red")
# Out:
# Overwriting streamlitapp.py

# %%
# !npm install -g localtunnel
# Out:
# ⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏
# added 22 packages in 2s
# ⠏
# ⠏3 packages are looking for funding
# ⠏  run `npm fund` for details
# ⠏

# %%
# !curl ipv4.icanhazip.com
# Out:
# 35.245.205.74

# %%
# !streamlit run streamlitapp.py & >./logs.txt & npx localtunnel --port 8501 & curl ipv4.icanhazip.com
# Out:
# 35.245.205.74
# ⠙
# ...
#
# ⠹⠸⠼⠴⠦⠧
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://172.28.0.12:8501
#   External URL: http://35.245.205.74:8501
#
# ⠇⠏⠋⠙⠹⠸⠼your url is: https://dark-cooks-clap.loca.lt
# ────────────────────────── Traceback (most recent call last) ───────────────────────────
#   /usr/local/lib/python3.12/dist-packages/streamlit/elements/lib/image_utils.py:291 in
#   image_to_url
# ────────────────────────────────────────────────────────────────────────────────────────
# FileNotFoundError: [Errno 2] No such file or directory: 'image_url'
#
# During handling of the above exception, another exception occurred:
#
# ────────────────────────── Traceback (most recent call last) ───────────────────────────
#   /usr/local/lib/python3.12/dist-packages/streamlit/runtime/memory_media_file_storage.
#   py:164 in _read_file
# ────────────────────────────────────────────────────────────────────────────────────────
# ...
